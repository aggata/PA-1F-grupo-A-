# %% [markdown]
# <a href="https://colab.research.google.com/github/aggata/PA-1F-grupo-A-/blob/main/Aula_dia_17_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 números

# Entrada

a = int(input( "Digite um número: "))
b = int(input("Digite um número: "))

# Processamento

soma = a + b

# Saída
print("")
print("-----------------------OPERADORES ARITIMÉTICOS--------------------")
print("")
print("--------------------------------SOMA------------------------------")
print("")
print (f"O resultado da SOMA de {a} MAIS {b} é igual a : {soma}")
print("")
print("------------------------------------------------------------------")
# Out:
# Digite um número: 15
# Digite um número: 15
#
# -----------------------OPERADORES ARITIMÉTICOS--------------------
#
# --------------------------------SOMA------------------------------
#
# O resultado da SOMA de 15 MAIS 15 é igual a : 30
#
# ------------------------------------------------------------------

# %%
# Fazer um programa para converter a temperatura
# F= (C × 9/5) + 32

# Entrada

c = float (input("digite a temperatura em celsius:"))

# Processamento

f = (c * 9/5) + 32

# Saída

print (f"A temperatura em Fahrenheit é: {f}")
# Out:
# digite a temperatura em celsius:23
# A temperatura em Fahrenheit é: 73.4

# %%
# Operadores Aritiméticos
# Fazer um programa que calcula operações com 02 números

# Entrada

a = int(input("Digite um número: "))
b = int(input("Digite um número: "))

# Processamento

subtração = a - b

# Saída
print("")
print("-----------------------OPERADORES ARITIMÉTICOS---------------------")
print("")
print("----------------------------SUBTRAÇÃO------------------------------")
print("")
print (f"O resultado da SUBTRAÇÃO de {a} MENOS {b} é igual a : {subtração}")
print("")
print("-------------------------------------------------------------------")
# Out:
# Digite um número: 5
# Digite um número: 8
#
# -----------------------OPERADORES ARITIMÉTICOS---------------------
#
# ----------------------------SUBTRAÇÃO------------------------------
#
# O resultado da SUBTRAÇÃO de 5 MENOS 8 é igual a : -3
#
# -------------------------------------------------------------------

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 números

# Entrada

a = int(input("Digite um número: "))
b = int(input("Digite um número: "))

#  Processamento

multiplicação = a * b

# Saída
print("")
print("-----------------------OPERADORES ARITIMÉTICOS---------------------")
print("")
print("----------------------------MULTIPLICAÇÃO--------------------------")
print("")
print (f"O resultado da MULTIPLICAÇÃO de {a} VEZES {b} é igual a : {multiplicação}")
print("")
print("-------------------------------------------------------------------")
# Out:
# Digite um número: 9
# Digite um número: 7
#
# -----------------------OPERADORES ARITIMÉTICOS---------------------
#
# ----------------------------MULTIPLICAÇÃO--------------------------
#
# O resultado da MULTIPLICAÇÃO de 9 VEZES 7 é igual a : 63
#
# -------------------------------------------------------------------

# %%
# Operadores Aritiméticos
# Fazer um programa que calcula a operação de 02 números

# Entrada

a = int(input("Digite um número: "))
b = int(input("Digite um número: "))

# Processamento

divisão = a / b

# Saída
print("")
print("----------------------------OPERADORES ARITIMÉTICOS-------------------")
print("")
print("----------------------------DIVISÃO-----------------------------------")
print("")
print (f" O resutado da Divisão de {a} DIVIDIDO POR {b} é igual a : {divisão}")
print("")
print("----------------------------------------------------------------------")
# Out:
# Digite um número: 9
# Digite um número: 5
#
# ----------------------------OPERADORES ARITIMÉTICOS-------------------
#
# ----------------------------DIVISÃO-----------------------------------
#
#  O resutado da Divisão de 9 DIVIDIDO POR 5 é igual a : 1.8
#
# ----------------------------------------------------------------------

# %%
# Operadores Aritiméticos
# Fazer um programa que calcula operação de  02 números

# Entrada

a = int(input("Digite um número:"))
b = int(input("Digie um número: "))

#Processamento

total = a // b

# Saída
print("")
print("----------------------------OPERADORES ARITIMÉTICOS-------------------")
print("")
print("-----------------------------DIVISÃO INTEIRA--------------------------")
print("")
print(f"O resultado da Divisão Inteira de {a} DIVIDIDO POR {b} é igual a : {total}")
print("")
print("---------------------------------------------------------------------")
# Out:
# Digite um número:6
# Digie um número: 6
#
# ----------------------------OPERADORES ARITIMÉTICOS-------------------
#
# -----------------------------DIVISÃO INTEIRA--------------------------
#
# O resultado da Divisão Inteira de 6 DIVIDIDO POR 6 é igual a : 1
#
# ---------------------------------------------------------------------

# %%
# Entrada

a = int(input("Digite um número:"))
b = int(input("Digite um número: "))

# Processamento

resto = a % b

# Saída
print("")
print("----------------------------OPERADORES ARITIMÉTICOS------------------")
print("")
print("------------------------------RESTO DA DIVISÃO-----------------------")
print("")
print(f"O resultado do RESTO DA DIVISÃO de {a} DIVIDIDO POR {b} é igual a : {resto}")
print("")
print("---------------------------------------------------------------------")
# Out:
# Digite um número:5
# Digite um número: 8
#
# ----------------------------OPERADORES ARITIMÉTICOS------------------
#
# ------------------------------RESTO DA DIVISÃO-----------------------
#
# O resultado do RESTO DA DIVISÃO de 5 DIVIDIDO POR 8 é igual a : 5
#
# ---------------------------------------------------------------------

# %%
# Entrada

a = int(input("Digite um número:"))
b = int(input("Digite um número: "))

# Processamento

potência = a ** b

# Saída
print("")
print("----------------------------OPERADORES ARITIMÉTICOS------------------")
print("")
print("------------------------------POTÊNCIA-------------------------------")
print(f"O resultado da POTÊNCIA de {a} elevado a {b} é igual a :{potência}")
print("")
print("---------------------------------------------------------------------")
# Out:
# Digite um número:8
# Digite um número: 9
#
# ----------------------------OPERADORES ARITIMÉTICOS------------------
#
# ------------------------------POTÊNCIA-------------------------------
# O resultado da POTÊNCIA de 8 elevado a 9 é igual a :134217728
#
# ---------------------------------------------------------------------

# %%
# Fazer um programa para converter a temperatura
# F= (C × 9/5) + 32

# Entrada

c = float (input("digite a temperatura em celsius:"))

# Processamento

f = (c * 9/5) + 32

# Saída

print(f"A temperatura em Fahrenheit é: {f}")
# Out:
# digite a temperatura em celsius:9
# A temperatura em Fahrenheit é: 48.2

# %%
# Fazer um programa que converte km em metros
# F= multiplique o valor de comprimento por 1000

# Entrada

km = float (input("digite a distância em km:"))

# Processamento

m = km * 1000

# Saída

print(f"A distância em metros é: {m}")
# Out:
# digite a distância em km:67
# A distância em metros é: 67000.0

# %%
# Fazer um programa que converte horas em minutos
# multiplique o valor de tempo por 60

# Entrada

horas = float (input("digite o tempo em horas:"))

# Processamento

minutos = horas * 60

# Saída

print(f"O tempo em minutos é: {minutos}")
# Out:
# digite o tempo em horas:4
# O tempo em minutos é: 240.0
