# %% [markdown]
# <a href="https://colab.research.google.com/github/aggata/PA-1F-grupo-A-/blob/main/aula_02_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.random()

print (a)
# Out:
# 0.7607363896368246

# %%
import random

a = random.randint(0, 100)

print(a)
# Out:
# 44

# %% [markdown]
# Fazer um jogo de advinhação
# O usuário irá digitar um número, o programa deverá imprimir uma mensagem se o palpite do usuário é maior ou menor que o numero secreto, o programa deverá imprimir uma mensagem de quente, morno ou frio
#
# REGRA
# Se a diferença do palpite para o número secreto for 3 - frio, 2 - morno e 1 - quente

# %%
import random

a = random.randint(0, 100)

palpite = int(input("Digite um número: "))
diferenca = a - palpite
diferenca = a == palpite
diferenca = abs(diferenca)
print(f"O número secreto é {67} ")
print(f"O palpite do usuário é {palpite}")
print(f"A diferença do palpite para o número secreto é {diferenca}")



if diferenca == 0:
    print("Você acertou!")
elif diferenca <= 5:
    print("Está quente!")
elif diferenca <= 15:
    print("Está morno.")
elif diferenca <= 30:
    print("Está frio.")
else:
    print("Está muito longe!")
# Out:
# Digite um número: 62
# O número secreto é 67
# O palpite do usuário é 62
# A diferença do palpite para o número secreto é 0
# Você acertou!
